# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %%
# First we read in the airline passenger
fileName = "data/international-airline-passengers.csv"
#fileName = "data/wolfer-sunspot-numbers-1770-to-1.csv"
#fileName ='data/EURUSD_15m_BID_01.01.2010-31.12.2016.csv'
#fileName ='data/total-annual-rainfall-in-inches-.csv'

# Load the data
df = pd.read_csv(fileName, engine='python', skipfooter=3)

# Depending on the dataset that we use, the name of the 'Time' column is different
if(fileName=='data/international-airline-passengers.csv'):
    time_column_name = 'Month'
elif(fileName=='data/wolfer-sunspot-numbers-1770-to-1.csv'):
    time_column_name='Year'
elif(fileName=='data/EURUSD_15m_BID_01.01.2010-31.12.2016.csv'):
    time_column_name='Time'
    df = df[['Time', 'Close']].copy()
elif(fileName=='data/total-annual-rainfall-in-inches-.csv'):
    time_column_name='Year'

# Convert the time column into appropriate format
df[time_column_name]=pd.to_datetime(df[time_column_name], format='%Y-%m-%d')
df.set_index([time_column_name], inplace=True)


if(fileName=='data/EURUSD_15m_BID_01.01.2010-31.12.2016.csv'):
    
    # Split the data set into training and test sets
    train_data = df['2016-01-01 00:00':'2016-05-01 00:00']
    test_data = df['2016-05-01 00:15':'2016-06-30 23:45']
    
    # Convert the training and test set into a flattened array
    time_vals = df[train_data.index[0]:test_data.index[len(test_data)-1]]
    train_data = train_data.values.astype('float32')
    test_data = test_data.values.astype('float32')
    number_of_epochs=10 # The number of epochs for training
    activation_func = 'relu'
    
    # Extract the raw data, without the dates
elif(fileName=='data/wolfer-sunspot-numbers-1770-to-1.csv'):
    
    # Convert the training and test set into a flattened array
    time_vals = df[df.index[0]:df.index[len(df)-1]]
    data = df.values
    data = data.astype('float32')
    
    # Now we split the data  into test and train
    split = 71
    train_data =  data[0:split,:]
    test_data = data[split:,:]
    number_of_epochs=300
    activation_func = 'relu'
    
    
elif(fileName=='data/international-airline-passengers.csv'):
    
    # Convert the training and test set into a flattened array, collect time indices
    # for plotting later
    time_vals = df[df.index[0]:df.index[len(df)-1]]
    data = df.values
    data = data.astype('float32')
    
    # Now we split the data into training and testing
    split = 73
    train_data =  data[0:split,:]
    test_data = data[split:,:]
    number_of_epochs=300
    activation_func = 'relu'

elif(fileName=='data/total-annual-rainfall-in-inches-.csv'):
    
    # Convert the training and test set into a flattened array, collect time indices
    # for plotting later
    time_vals = df[df.index[0]:df.index[len(df)-1]]
    data = df.values
    data = data.astype('float32')
    
    # Now we split the data into training and testing sets and apply the data scaling
    split = 70
    train_data =  data[0:split,:]
    test_data = data[split:,:]
    number_of_epochs=300
    activation_func = 'relu'

# Print the training data
print("train data", train_data.shape)
print('Activation Function: ', activation_func)

def future_data(data,lags=1,future=1):
    '''
    This function, takes in the time series [X_t] and returns the array
    X=[X_{t-1}]
    Y=[X_t]
    '''
    
    X, y = [], []
    for row in range(len(data) - lags - future):
        a = data[row:(row + lags), 0]
        X.append(a)
        y.append(data[row + lags+future-1, 0])
    return np.array(X), np.array(y)

def scale_array(y_vec):
    '''
    This scales the input data according to the transformation:
    
    F(xi)=(xi-xmin)/(x_max - x_min)
    
    This assures that the data set is in the range [0,1]
    
    '''
    
    # Compute the max and min of the vectors
    ymax = np.max(y_vec)
    ymin = np.min(y_vec)
    
    y_vec_scaled = np.zeros((len(y_vec),1))
    
    # Scale all data points
    for k in range(0,len(y_vec)):
        y_vec_scaled[k][0] = (y_vec[k][0]-ymin)/(ymax-ymin)
    
    return y_vec_scaled,ymin,ymax

def invert_scaling(y_vec_scaled,ymin,ymax):
    '''
    This function inverts the scaling transformation
    '''
    
    y_vec = np.zeros(y_vec_scaled.shape)
        
        
    for k in range(0,len(y_vec_scaled)):
        y_vec[k] = ymin+(ymax-ymin)*y_vec_scaled[k]
    
    return y_vec

# Process the train and test data by scaling it
train_data,train_min,train_max = scale_array(train_data)
test_data,test_min,test_max = scale_array(test_data)

# Here we choose the number of lags for the data set, and how far into the future we are planning to predict
lags=1
future=1

# Process the training and testing data
X_train, y_train = future_data(train_data, lags,future)
X_test, y_test = future_data(test_data, lags,future)
# Out:
# train data (73, 1)
# Activation Function:  relu

# %%
# Create and fit Feed forward neural network model
model = Sequential()
model.add(Dense(4, input_dim=lags, activation=activation_func))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Store the history of the model to plot the progress
history=model.fit(X_train, y_train, epochs=number_of_epochs, batch_size=2, verbose=1)
# Out:
# Epoch 1/300
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0722
# Epoch 2/300
# 71/71 [==============================] - 0s 386us/step - loss: 0.0321
# Epoch 3/300
# 71/71 [==============================] - 0s 554us/step - loss: 0.0174
# Epoch 4/300
# 71/71 [==============================] - 0s 477us/step - loss: 0.0135
# Epoch 5/300
# 71/71 [==============================] - 0s 378us/step - loss: 0.0125
# Epoch 6/300
# 71/71 [==============================] - 0s 410us/step - loss: 0.0118
# Epoch 7/300
# 71/71 [==============================] - 0s 454us/step - loss: 0.0114
# Epoch 8/300
# 71/71 [==============================] - 0s 369us/step - loss: 0.0111
# Epoch 9/300
# 71/71 [==============================] - 0s 511us/step - loss: 0.0108
# Epoch 10/300
# 71/71 [==============================] - 0s 392us/step - loss: 0.0105
# Epoch 11/300
# 71/71 [==============================] - 0s 444us/step - loss: 0.0103
# Epoch 12/300
# 71/71 [==============================] - 0s 482us/step - loss: 0.0101
# Epoch 13/300
# 71/71 [==============================] - 0s 469us/step - loss: 0.0100
# Epoch 14/300
# 71/71 [==============================] - 0s 415us/step - loss: 0.0099
# Epoch 15/300
# 71/71 [==============================] - 0s 498us/step - loss: 0.0097
# Epoch 16/300
# 71/71 [==============================] - 0s 493us/step - loss: 0.0096
# Epoch 17/300
# 71/71 [==============================] - 0s 485us/step - loss: 0.0095
# Epoch 18/300
# 71/71 [==============================] - 0s 531us/step - loss: 0.0094
# Epoch 19/300
# 71/71 [==============================] - 0s 533us/step - loss: 0.0094
# Epoch 20/300
# 71/71 [==============================] - 0s 435us/step - loss: 0.0093
# Epoch 21/300
# 71/71 [==============================] - 0s 399us/step - loss: 0.0093
# Epoch 22/300
# 71/71 [==============================] - 0s 388us/step - loss: 0.0091
# Epoch 23/300
# 71/71 [==============================] - 0s 482us/step - loss: 0.0091
# Epoch 24/300
# 71/71 [==============================] - 0s 479us/step - loss: 0.0091
# Epoch 25/300
# 71/71 [==============================] - 0s 486us/step - loss: 0.0091
# Epoch 26/300
# 71/71 [==============================] - 0s 488us/step - loss: 0.0091
# Epoch 27/300
# 71/71 [==============================] - 0s 400us/step - loss: 0.0091
# Epoch 28/300
# 71/71 [==============================] - 0s 541us/step - loss: 0.0091
# Epoch 29/300
# 71/71 [==============================] - 0s 447us/step - loss: 0.0090
# Epoch 30/300
# 71/71 [==============================] - 0s 492us/step - loss: 0.0092
# Epoch 31/300
# 71/71 [==============================] - 0s 433us/step - loss: 0.0091
# Epoch 32/300
# 71/71 [==============================] - 0s 475us/step - loss: 0.0089
# Epoch 33/300
# 71/71 [==============================] - 0s 504us/step - loss: 0.0089
# Epoch 34/300
# 71/71 [==============================] - 0s 434us/step - loss: 0.0089
# Epoch 35/300
# 71/71 [==============================] - 0s 433us/step - loss: 0.0089
# Epoch 36/300
# 71/71 [==============================] - 0s 468us/step - loss: 0.0089
# Epoch 37/300
# 71/71 [==============================] - 0s 427us/step - loss: 0.0092
# Epoch 38/300
# 71/71 [==============================] - 0s 489us/step - loss: 0.0089
# Epoch 39/300
# 71/71 [==============================] - 0s 474us/step - loss: 0.0089
# Epoch 40/300
# 71/71 [==============================] - 0s 514us/step - loss: 0.0090
# Epoch 41/300
# 71/71 [==============================] - 0s 444us/step - loss: 0.0088
# Epoch 42/300
# 71/71 [==============================] - 0s 425us/step - loss: 0.0090
# Epoch 43/300
# 71/71 [==============================] - 0s 378us/step - loss: 0.0088
# Epoch 44/300
# 71/71 [==============================] - 0s 500us/step - loss: 0.0089
# Epoch 45/300
# 71/71 [==============================] - 0s 519us/step - loss: 0.0089
# Epoch 46/300
# 71/71 [==============================] - 0s 540us/step - loss: 0.0089
# Epoch 47/300
# 71/71 [==============================] - 0s 383us/step - loss: 0.0090
# Epoch 48/300
# 71/71 [==============================] - 0s 483us/step - loss: 0.0091
# Epoch 49/300
# 71/71 [==============================] - 0s 390us/step - loss: 0.0089
# Epoch 50/300
# 71/71 [==============================] - 0s 392us/step - loss: 0.0090
# Epoch 51/300
# 71/71 [==============================] - 0s 451us/step - loss: 0.0089
# Epoch 52/300
# 71/71 [==============================] - 0s 483us/step - loss: 0.0089
# Epoch 53/300
# 71/71 [==============================] - 0s 386us/step - loss: 0.0088
# Epoch 54/300
# 71/71 [==============================] - 0s 381us/step - loss: 0.0089
# Epoch 55/300
# 71/71 [==============================] - 0s 523us/step - loss: 0.0088
# Epoch 56/300
# 71/71 [==============================] - 0s 467us/step - loss: 0.0089
# Epoch 57/300
# 71/71 [==============================] - 0s 388us/step - loss: 0.0089
# Epoch 58/300
# 71/71 [==============================] - 0s 312us/step - loss: 0.0089
# Epoch 59/300
# 71/71 [==============================] - 0s 458us/step - loss: 0.0088
# Epoch 60/300
# 71/71 [==============================] - 0s 392us/step - loss: 0.0089
# Epoch 61/300
# 71/71 [==============================] - 0s 389us/step - loss: 0.0090
# Epoch 62/300
# 71/71 [==============================] - 0s 401us/step - loss: 0.0090
# Epoch 63/300
# 71/71 [==============================] - 0s 450us/step - loss: 0.0089
# Epoch 64/300
# 71/71 [==============================] - 0s 446us/step - loss: 0.0089
# Epoch 65/300
# 71/71 [==============================] - 0s 381us/step - loss: 0.0089
# Epoch 66/300
# 71/71 [==============================] - 0s 375us/step - loss: 0.0088
# Epoch 67/300
# 71/71 [==============================] - 0s 367us/step - loss: 0.0089
# Epoch 68/300
# 71/71 [==============================] - 0s 557us/step - loss: 0.0090
# Epoch 69/300
# 71/71 [==============================] - 0s 413us/step - loss: 0.0089
# Epoch 70/300
# 71/71 [==============================] - 0s 434us/step - loss: 0.0088
# Epoch 71/300
# 71/71 [==============================] - 0s 462us/step - loss: 0.0089
# Epoch 72/300
# 71/71 [==============================] - 0s 383us/step - loss: 0.0089
# Epoch 73/300
# 71/71 [==============================] - 0s 398us/step - loss: 0.0089
# Epoch 74/300
# 71/71 [==============================] - 0s 436us/step - loss: 0.0088
# Epoch 75/300
# 71/71 [==============================] - 0s 481us/step - loss: 0.0089
# Epoch 76/300
# 71/71 [==============================] - 0s 395us/step - loss: 0.0089
# Epoch 77/300
# 71/71 [==============================] - 0s 380us/step - loss: 0.0091
# Epoch 78/300
# 71/71 [==============================] - 0s 381us/step - loss: 0.0089
# Epoch 79/300
# 71/71 [==============================] - 0s 346us/step - loss: 0.0089
# Epoch 80/300
# 71/71 [==============================] - 0s 395us/step - loss: 0.0089
# Epoch 81/300
# 71/71 [==============================] - 0s 472us/step - loss: 0.0088
# Epoch 82/300
# 71/71 [==============================] - 0s 426us/step - loss: 0.0089
# Epoch 83/300
# 71/71 [==============================] - 0s 412us/step - loss: 0.0091
# Epoch 84/300
# 71/71 [==============================] - 0s 329us/step - loss: 0.0089
# Epoch 85/300
# 71/71 [==============================] - 0s 466us/step - loss: 0.0088
# Epoch 86/300
# 71/71 [==============================] - 0s 447us/step - loss: 0.0088
# Epoch 87/300
# 71/71 [==============================] - 0s 402us/step - loss: 0.0088
# Epoch 88/300
# 71/71 [==============================] - 0s 373us/step - loss: 0.0089
# Epoch 89/300
# 71/71 [==============================] - 0s 391us/step - loss: 0.0089
# Epoch 90/300
# 71/71 [==============================] - 0s 412us/step - loss: 0.0090
# Epoch 91/300
# 71/71 [==============================] - 0s 488us/step - loss: 0.0089
# Epoch 92/300
# 71/71 [==============================] - 0s 338us/step - loss: 0.0089
# Epoch 93/300
# 71/71 [==============================] - 0s 401us/step - loss: 0.0089
# Epoch 94/300
# 71/71 [==============================] - 0s 444us/step - loss: 0.0089
# Epoch 95/300
# 71/71 [==============================] - 0s 415us/step - loss: 0.0089
# Epoch 96/300
# 71/71 [==============================] - 0s 370us/step - loss: 0.0089
# Epoch 97/300
# 71/71 [==============================] - 0s 444us/step - loss: 0.0088
# Epoch 98/300
# 71/71 [==============================] - 0s 379us/step - loss: 0.0089
# Epoch 99/300
# 71/71 [==============================] - 0s 422us/step - loss: 0.0089
# Epoch 100/300
# 71/71 [==============================] - 0s 443us/step - loss: 0.0090
# Epoch 101/300
# 71/71 [==============================] - 0s 409us/step - loss: 0.0089
# Epoch 102/300
# 71/71 [==============================] - 0s 363us/step - loss: 0.0088
# Epoch 103/300
# 71/71 [==============================] - 0s 378us/step - loss: 0.0088
# Epoch 104/300
# 71/71 [==============================] - 0s 449us/step - loss: 0.0088
# Epoch 105/300
# 71/71 [==============================] - 0s 424us/step - loss: 0.0090
# Epoch 106/300
# 71/71 [==============================] - 0s 338us/step - loss: 0.0090
# Epoch 107/300
# 71/71 [==============================] - 0s 409us/step - loss: 0.0091
# Epoch 108/300
# 71/71 [==============================] - 0s 394us/step - loss: 0.0091
# Epoch 109/300
# 71/71 [==============================] - 0s 423us/step - loss: 0.0088
# Epoch 110/300
# 71/71 [==============================] - 0s 366us/step - loss: 0.0090
# Epoch 111/300
# 71/71 [==============================] - 0s 398us/step - loss: 0.0089
# Epoch 112/300
# 71/71 [==============================] - 0s 481us/step - loss: 0.0092
# Epoch 113/300
# 71/71 [==============================] - 0s 457us/step - loss: 0.0092
# Epoch 114/300
# 71/71 [==============================] - 0s 417us/step - loss: 0.0087
# Epoch 115/300
# 71/71 [==============================] - 0s 422us/step - loss: 0.0089
# Epoch 116/300
# 71/71 [==============================] - 0s 355us/step - loss: 0.0089
# Epoch 117/300
# 71/71 [==============================] - 0s 417us/step - loss: 0.0092
# Epoch 118/300
# 71/71 [==============================] - 0s 374us/step - loss: 0.0088
# Epoch 119/300
# 71/71 [==============================] - 0s 429us/step - loss: 0.0088
# Epoch 120/300
# 71/71 [==============================] - 0s 386us/step - loss: 0.0089
# Epoch 121/300
# 71/71 [==============================] - 0s 360us/step - loss: 0.0090
# Epoch 122/300
# 71/71 [==============================] - 0s 391us/step - loss: 0.0089
# Epoch 123/300
# 71/71 [==============================] - 0s 491us/step - loss: 0.0091
# Epoch 124/300
# 71/71 [==============================] - 0s 464us/step - loss: 0.0088
# Epoch 125/300
# 71/71 [==============================] - 0s 420us/step - loss: 0.0088
# Epoch 126/300
# 71/71 [==============================] - 0s 425us/step - loss: 0.0089
# Epoch 127/300
# 71/71 [==============================] - 0s 398us/step - loss: 0.0091
# Epoch 128/300
# 71/71 [==============================] - 0s 364us/step - loss: 0.0090
# Epoch 129/300
# 71/71 [==============================] - 0s 407us/step - loss: 0.0088
# Epoch 130/300
# 71/71 [==============================] - 0s 406us/step - loss: 0.0090
# Epoch 131/300
# 71/71 [==============================] - 0s 518us/step - loss: 0.0090
# Epoch 132/300
# 71/71 [==============================] - 0s 325us/step - loss: 0.0089
# Epoch 133/300
# 71/71 [==============================] - 0s 405us/step - loss: 0.0089
# Epoch 134/300
# 71/71 [==============================] - 0s 373us/step - loss: 0.0088
# Epoch 135/300
# 71/71 [==============================] - 0s 380us/step - loss: 0.0089
# Epoch 136/300
# 71/71 [==============================] - 0s 461us/step - loss: 0.0090
# Epoch 137/300
# 71/71 [==============================] - 0s 365us/step - loss: 0.0088
# Epoch 138/300
# 71/71 [==============================] - 0s 423us/step - loss: 0.0088
# Epoch 139/300
# 71/71 [==============================] - 0s 345us/step - loss: 0.0089
# Epoch 140/300
# 71/71 [==============================] - 0s 466us/step - loss: 0.0089
# Epoch 141/300
# 71/71 [==============================] - 0s 370us/step - loss: 0.0088
# Epoch 142/300
# 71/71 [==============================] - 0s 395us/step - loss: 0.0088
# Epoch 143/300
# 71/71 [==============================] - 0s 378us/step - loss: 0.0090
# Epoch 144/300
# 71/71 [==============================] - 0s 438us/step - loss: 0.0089
# Epoch 145/300
# 71/71 [==============================] - 0s 388us/step - loss: 0.0090
# Epoch 146/300
# 71/71 [==============================] - 0s 470us/step - loss: 0.0089
# Epoch 147/300
# 71/71 [==============================] - 0s 387us/step - loss: 0.0088
# Epoch 148/300
# 71/71 [==============================] - 0s 406us/step - loss: 0.0091
# Epoch 149/300
# 71/71 [==============================] - 0s 403us/step - loss: 0.0088
# Epoch 150/300
# 71/71 [==============================] - 0s 419us/step - loss: 0.0089
# Epoch 151/300
# 71/71 [==============================] - 0s 425us/step - loss: 0.0092
# Epoch 152/300
# 71/71 [==============================] - 0s 388us/step - loss: 0.0089
# Epoch 153/300
# 71/71 [==============================] - 0s 386us/step - loss: 0.0089
# Epoch 154/300
# 71/71 [==============================] - 0s 371us/step - loss: 0.0089
# Epoch 155/300
# 71/71 [==============================] - 0s 440us/step - loss: 0.0091
# Epoch 156/300
# 71/71 [==============================] - 0s 438us/step - loss: 0.0088
# Epoch 157/300
# 71/71 [==============================] - 0s 530us/step - loss: 0.0089
# Epoch 158/300
# 71/71 [==============================] - 0s 470us/step - loss: 0.0090
# Epoch 159/300
# 71/71 [==============================] - 0s 440us/step - loss: 0.0090
# Epoch 160/300
# 71/71 [==============================] - 0s 383us/step - loss: 0.0089
# Epoch 161/300
# 71/71 [==============================] - 0s 367us/step - loss: 0.0091
# Epoch 162/300
# 71/71 [==============================] - 0s 397us/step - loss: 0.0090
# Epoch 163/300
# 71/71 [==============================] - 0s 391us/step - loss: 0.0088
# Epoch 164/300
# 71/71 [==============================] - 0s 412us/step - loss: 0.0088
# Epoch 165/300
# 71/71 [==============================] - 0s 467us/step - loss: 0.0088
# Epoch 166/300
# 71/71 [==============================] - 0s 430us/step - loss: 0.0089
# Epoch 167/300
# 71/71 [==============================] - 0s 431us/step - loss: 0.0090
# Epoch 168/300
# 71/71 [==============================] - 0s 423us/step - loss: 0.0089
# Epoch 169/300
# 71/71 [==============================] - 0s 394us/step - loss: 0.0088
# Epoch 170/300
# 71/71 [==============================] - 0s 408us/step - loss: 0.0094
# Epoch 171/300
# 71/71 [==============================] - 0s 441us/step - loss: 0.0089
# Epoch 172/300
# 71/71 [==============================] - 0s 441us/step - loss: 0.0090
# Epoch 173/300
# 71/71 [==============================] - 0s 427us/step - loss: 0.0090
# Epoch 174/300
# 71/71 [==============================] - 0s 389us/step - loss: 0.0089
# Epoch 175/300
# 71/71 [==============================] - 0s 414us/step - loss: 0.0089
# Epoch 176/300
# 71/71 [==============================] - 0s 384us/step - loss: 0.0088
# Epoch 177/300
# 71/71 [==============================] - 0s 415us/step - loss: 0.0090
# Epoch 178/300
# 71/71 [==============================] - 0s 419us/step - loss: 0.0089
# Epoch 179/300
# 71/71 [==============================] - 0s 387us/step - loss: 0.0089
# Epoch 180/300
# 71/71 [==============================] - 0s 488us/step - loss: 0.0089
# Epoch 181/300
# 71/71 [==============================] - 0s 407us/step - loss: 0.0088
# Epoch 182/300
# 71/71 [==============================] - 0s 402us/step - loss: 0.0088
# Epoch 183/300
# 71/71 [==============================] - 0s 411us/step - loss: 0.0088
# Epoch 184/300
# 71/71 [==============================] - 0s 390us/step - loss: 0.0088
# Epoch 185/300
# 71/71 [==============================] - 0s 474us/step - loss: 0.0088
# Epoch 186/300
# 71/71 [==============================] - 0s 313us/step - loss: 0.0089
# Epoch 187/300
# 71/71 [==============================] - 0s 538us/step - loss: 0.0088
# Epoch 188/300
# 71/71 [==============================] - 0s 402us/step - loss: 0.0088
# Epoch 189/300
# 71/71 [==============================] - 0s 476us/step - loss: 0.0089
# Epoch 190/300
# 71/71 [==============================] - 0s 377us/step - loss: 0.0088
# Epoch 191/300
# 71/71 [==============================] - 0s 365us/step - loss: 0.0090
# Epoch 192/300
# 71/71 [==============================] - 0s 413us/step - loss: 0.0091
# Epoch 193/300
# 71/71 [==============================] - 0s 413us/step - loss: 0.0088
# Epoch 194/300
# 71/71 [==============================] - 0s 422us/step - loss: 0.0088
# Epoch 195/300
# 71/71 [==============================] - 0s 386us/step - loss: 0.0088
# Epoch 196/300
# 71/71 [==============================] - 0s 331us/step - loss: 0.0093
# Epoch 197/300
# 71/71 [==============================] - 0s 426us/step - loss: 0.0088
# Epoch 198/300
# 71/71 [==============================] - 0s 522us/step - loss: 0.0091
# Epoch 199/300
# 71/71 [==============================] - 0s 380us/step - loss: 0.0088
# Epoch 200/300
# 71/71 [==============================] - 0s 464us/step - loss: 0.0088
# Epoch 201/300
# 71/71 [==============================] - 0s 440us/step - loss: 0.0088
# Epoch 202/300
# 71/71 [==============================] - 0s 405us/step - loss: 0.0089
# Epoch 203/300
# 71/71 [==============================] - 0s 509us/step - loss: 0.0089
# Epoch 204/300
# 71/71 [==============================] - 0s 442us/step - loss: 0.0089
# Epoch 205/300
# 71/71 [==============================] - 0s 461us/step - loss: 0.0088
# Epoch 206/300
# 71/71 [==============================] - 0s 459us/step - loss: 0.0089
# Epoch 207/300
# 71/71 [==============================] - 0s 439us/step - loss: 0.0089
# Epoch 208/300
# 71/71 [==============================] - 0s 382us/step - loss: 0.0088
# Epoch 209/300
# 71/71 [==============================] - 0s 458us/step - loss: 0.0089
# Epoch 210/300
# 71/71 [==============================] - 0s 465us/step - loss: 0.0088
# Epoch 211/300
# 71/71 [==============================] - 0s 454us/step - loss: 0.0088
# Epoch 212/300
# 71/71 [==============================] - 0s 426us/step - loss: 0.0089
# Epoch 213/300
# 71/71 [==============================] - 0s 392us/step - loss: 0.0089
# Epoch 214/300
# 71/71 [==============================] - 0s 453us/step - loss: 0.0088
# Epoch 215/300
# 71/71 [==============================] - 0s 427us/step - loss: 0.0091
# Epoch 216/300
# 71/71 [==============================] - 0s 450us/step - loss: 0.0088
# Epoch 217/300
# 71/71 [==============================] - 0s 456us/step - loss: 0.0089
# Epoch 218/300
# 71/71 [==============================] - 0s 413us/step - loss: 0.0089
# Epoch 219/300
# 71/71 [==============================] - 0s 456us/step - loss: 0.0088
# Epoch 220/300
# 71/71 [==============================] - 0s 398us/step - loss: 0.0088
# Epoch 221/300
# 71/71 [==============================] - 0s 436us/step - loss: 0.0088
# Epoch 222/300
# 71/71 [==============================] - 0s 452us/step - loss: 0.0089
# Epoch 223/300
# 71/71 [==============================] - 0s 418us/step - loss: 0.0090
# Epoch 224/300
# 71/71 [==============================] - 0s 445us/step - loss: 0.0090
# Epoch 225/300
# 71/71 [==============================] - 0s 427us/step - loss: 0.0089
# Epoch 226/300
# 71/71 [==============================] - 0s 368us/step - loss: 0.0089
# Epoch 227/300
# 71/71 [==============================] - 0s 369us/step - loss: 0.0090
# Epoch 228/300
# 71/71 [==============================] - 0s 448us/step - loss: 0.0088
# Epoch 229/300
# 71/71 [==============================] - 0s 422us/step - loss: 0.0088
# Epoch 230/300
# 71/71 [==============================] - 0s 378us/step - loss: 0.0090
# Epoch 231/300
# 71/71 [==============================] - 0s 355us/step - loss: 0.0089
# Epoch 232/300
# 71/71 [==============================] - 0s 424us/step - loss: 0.0088
# Epoch 233/300
# 71/71 [==============================] - 0s 423us/step - loss: 0.0088
# Epoch 234/300
# 71/71 [==============================] - 0s 368us/step - loss: 0.0089
# Epoch 235/300
# 71/71 [==============================] - 0s 367us/step - loss: 0.0088
# Epoch 236/300
# 71/71 [==============================] - 0s 385us/step - loss: 0.0090
# Epoch 237/300
# 71/71 [==============================] - 0s 407us/step - loss: 0.0089
# Epoch 238/300
# 71/71 [==============================] - 0s 427us/step - loss: 0.0090
# Epoch 239/300
# 71/71 [==============================] - 0s 366us/step - loss: 0.0090
# Epoch 240/300
# 71/71 [==============================] - 0s 375us/step - loss: 0.0088
# Epoch 241/300
# 71/71 [==============================] - 0s 360us/step - loss: 0.0094
# Epoch 242/300
# 71/71 [==============================] - 0s 374us/step - loss: 0.0089
# Epoch 243/300
# 71/71 [==============================] - 0s 495us/step - loss: 0.0089
# Epoch 244/300
# 71/71 [==============================] - 0s 406us/step - loss: 0.0089
# Epoch 245/300
# 71/71 [==============================] - 0s 411us/step - loss: 0.0088
# Epoch 246/300
# 71/71 [==============================] - 0s 360us/step - loss: 0.0088
# Epoch 247/300
# 71/71 [==============================] - 0s 452us/step - loss: 0.0088
# Epoch 248/300
# 71/71 [==============================] - 0s 364us/step - loss: 0.0088
# Epoch 249/300
# 71/71 [==============================] - 0s 384us/step - loss: 0.0089
# Epoch 250/300
# 71/71 [==============================] - 0s 368us/step - loss: 0.0088
# Epoch 251/300
# 71/71 [==============================] - 0s 397us/step - loss: 0.0088
# Epoch 252/300
# 71/71 [==============================] - 0s 499us/step - loss: 0.0088
# Epoch 253/300
# 71/71 [==============================] - 0s 347us/step - loss: 0.0089
# Epoch 254/300
# 71/71 [==============================] - 0s 459us/step - loss: 0.0088
# Epoch 255/300
# 71/71 [==============================] - 0s 443us/step - loss: 0.0088
# Epoch 256/300
# 71/71 [==============================] - 0s 431us/step - loss: 0.0089
# Epoch 257/300
# 71/71 [==============================] - 0s 474us/step - loss: 0.0089
# Epoch 258/300
# 71/71 [==============================] - 0s 380us/step - loss: 0.0088
# Epoch 259/300
# 71/71 [==============================] - 0s 412us/step - loss: 0.0089
# Epoch 260/300
# 71/71 [==============================] - 0s 496us/step - loss: 0.0088
# Epoch 261/300
# 71/71 [==============================] - 0s 481us/step - loss: 0.0089
# Epoch 262/300
# 71/71 [==============================] - 0s 483us/step - loss: 0.0088
# Epoch 263/300
# 71/71 [==============================] - 0s 453us/step - loss: 0.0088
# Epoch 264/300
# 71/71 [==============================] - 0s 382us/step - loss: 0.0089
# Epoch 265/300
# 71/71 [==============================] - 0s 389us/step - loss: 0.0089
# Epoch 266/300
# 71/71 [==============================] - 0s 459us/step - loss: 0.0089
# Epoch 267/300
# 71/71 [==============================] - 0s 389us/step - loss: 0.0089
# Epoch 268/300
# 71/71 [==============================] - 0s 419us/step - loss: 0.0089
# Epoch 269/300
# 71/71 [==============================] - 0s 475us/step - loss: 0.0088
# Epoch 270/300
# 71/71 [==============================] - 0s 502us/step - loss: 0.0088
# Epoch 271/300
# 71/71 [==============================] - 0s 446us/step - loss: 0.0088
# Epoch 272/300
# 71/71 [==============================] - 0s 395us/step - loss: 0.0089
# Epoch 273/300
# 71/71 [==============================] - 0s 355us/step - loss: 0.0088
# Epoch 274/300
# 71/71 [==============================] - 0s 377us/step - loss: 0.0088
# Epoch 275/300
# 71/71 [==============================] - 0s 410us/step - loss: 0.0090
# Epoch 276/300
# 71/71 [==============================] - 0s 412us/step - loss: 0.0089
# Epoch 277/300
# 71/71 [==============================] - 0s 384us/step - loss: 0.0092
# Epoch 278/300
# 71/71 [==============================] - 0s 443us/step - loss: 0.0090
# Epoch 279/300
# 71/71 [==============================] - 0s 344us/step - loss: 0.0089
# Epoch 280/300
# 71/71 [==============================] - 0s 480us/step - loss: 0.0089
# Epoch 281/300
# 71/71 [==============================] - 0s 348us/step - loss: 0.0090
# Epoch 282/300
# 71/71 [==============================] - 0s 390us/step - loss: 0.0089
# Epoch 283/300
# 71/71 [==============================] - 0s 461us/step - loss: 0.0089
# Epoch 284/300
# 71/71 [==============================] - 0s 391us/step - loss: 0.0089
# Epoch 285/300
# 71/71 [==============================] - 0s 392us/step - loss: 0.0090
# Epoch 286/300
# 71/71 [==============================] - 0s 406us/step - loss: 0.0090
# Epoch 287/300
# 71/71 [==============================] - 0s 403us/step - loss: 0.0089
# Epoch 288/300
# 71/71 [==============================] - 0s 394us/step - loss: 0.0089
# Epoch 289/300
# 71/71 [==============================] - 0s 410us/step - loss: 0.0089
# Epoch 290/300
# 71/71 [==============================] - 0s 424us/step - loss: 0.0091
# Epoch 291/300
# 71/71 [==============================] - 0s 351us/step - loss: 0.0088
# Epoch 292/300
# 71/71 [==============================] - 0s 425us/step - loss: 0.0090
# Epoch 293/300
# 71/71 [==============================] - 0s 294us/step - loss: 0.0088
# Epoch 294/300
# 71/71 [==============================] - 0s 364us/step - loss: 0.0089
# Epoch 295/300
# 71/71 [==============================] - 0s 420us/step - loss: 0.0091
# Epoch 296/300
# 71/71 [==============================] - 0s 456us/step - loss: 0.0090
# Epoch 297/300
# 71/71 [==============================] - 0s 426us/step - loss: 0.0088
# Epoch 298/300
# 71/71 [==============================] - 0s 410us/step - loss: 0.0088
# Epoch 299/300
# 71/71 [==============================] - 0s 375us/step - loss: 0.0089
# Epoch 300/300
# 71/71 [==============================] - 0s 456us/step - loss: 0.0087

# %%
# Summarize the Feed forward neural network model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4)                 8
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %%
#--------------------------------------------------------------------
# Here we plot the loss of the FFNN model with the number of Epochs in the training
#--------------------------------------------------------------------

print(history.history.keys())


if(fileName=='data/international-airline-passengers.csv'):
    loss_label = 'Loss_airline.pdf'
elif(fileName=='data/wolfer-sunspot-numbers-1770-to-1.csv'):
    loss_label = 'Loss_sunspot.pdf'
elif(fileName=='data/EURUSD_15m_BID_01.01.2010-31.12.2016.csv'):
    loss_label = 'Loss_EURUSD.pdf'
elif(fileName=='data/total-annual-rainfall-in-inches-.csv'):
    loss_label = 'Loss_rainfall.pdf'

plt.plot()
plt.plot(history.history['loss'],color='b')
plt.ylabel('Loss',fontsize=15)
plt.xlabel('Epoch',fontsize=20)
plt.savefig(loss_label,bboxes='tight')
plt.show()
# Out:
# dict_keys(['loss'])

# %%
# The number of random samples that we will use to generate uncertainty bands
uncertainty_samples = 100

# We generate predictions on the training and test data sets
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# We compute the residuals of the fitted model to the training set
residuals = np.abs(y_test.reshape(-1, 1) - test_predict.reshape(-1, 1))

# Here we estimate the average residual values and stdev.
sigma = 0.5*np.mean(residuals)
std_sigma =  0.5*np.std(residuals)
print("Estimated Sigma: ", sigma, np.std(residuals))

# Here we perturb the test set and generate predictions based on pertrubed data, to generate uncertainty bands
test_predictions = []
for k in range(0,uncertainty_samples):
    test_predict = model.predict(X_test)+np.random.normal(sigma, std_sigma, test_predict.shape)
    test_predictions.append(test_predict)

test_predictions = np.asarray(test_predictions)
y = test_predict.flatten()[future:]

def return_min_max_prediction(test_predictions,i):
    '''
    This function will return the maxium and minimum values of the sampled predictions
    in order to generate the uncertainty bands
    '''
    
    y_vec = [ test_predictions[k][i][0] for k in range(0,test_predictions.shape[0])]
    
    ymin = np.min(y_vec)
    ymax = np.max(y_vec)
    
    return ymin,ymax

# Compute the upper and lower bands of the sampled predictions
y_min = np.asarray([return_min_max_prediction(test_predictions,i)[0] for i in range(0,len(y))])
y_max = np.asarray([return_min_max_prediction(test_predictions,i)[1] for i in range(0,len(y))])
x = np.arange(-future,len(y_min)-future)


# Unscale all of the data, to produce data in the original set
y_test = invert_scaling(y_test,test_min,test_max)
y_min = invert_scaling(y_min,test_min,test_max)
y_max = invert_scaling(y_max,test_min,test_max)
y = invert_scaling(y,test_min,test_max)


# Compute the root mean squared error
mse = ((y_test[:-1].reshape(-1, 1) - y.reshape(-1, 1)) ** 2).mean()


print('-------------------------------------')
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
print('-------------------------------------')


#============================================================================================
# Unscale data
#test_predictions = scaler.inverse_transform(test_predictions)
y_train = invert_scaling(y_train,train_min,train_max)
train_predict = invert_scaling(train_predict,train_min,train_max)


x_test = range(len(y_train),len(y_train)+len(y_test))
x = range(len(y_train),len(y_train)+len(y))

plt.plot(y_train)
plt.plot(train_predict)
# Out:
# Estimated Sigma:  0.0455023582984 0.0591054342828
# -------------------------------------
# MSE:  524.280251298
# RMSE:  22.8971668837
# -------------------------------------

# %%
if(fileName=='data/international-airline-passengers.csv'):
    time_steps = 15
    time_format= "%Y"
    y_label = 'Number of Airline Passengers'
    output_name = 'Airline_Passengers_NN.pdf'
elif(fileName=='data/wolfer-sunspot-numbers-1770-to-1.csv'):
    time_steps = 10
    time_format= "%Y"
    y_label = 'Number of Sunspots'
    output_name = 'Sunspot_Forecast_NN.pdf'
elif(fileName=='data/EURUSD_15m_BID_01.01.2010-31.12.2016.csv'):
    time_format= "%m-%H:%M"
    time_steps = 2800
    y_label = 'Exchange Rate EUR/USD'
    output_name = 'EURO_USD_exchange_rate_NN.pdf'
elif(fileName=='data/total-annual-rainfall-in-inches-.csv'):
    time_format= "%Y"
    time_steps = 15
    y_label = 'Annual Rainfall [Inches] London'
    output_name = 'Annual_Rainfall_NN.pdf'

vals= range(0,len(y_train)+len(y_test),time_steps)
labels = [time_vals.index[k].strftime(time_format) for k in vals]

# Now we plot the predictions with the uncertainty bands 
plt.xticks(vals, labels)
plt.ylabel(y_label,fontsize=15)
plt.xlabel('Date',fontsize=20)
plt.plot(y_train, label='Training data',color='b');
plt.plot(x_test,y_test.reshape(-1, 1), label='Test Data', color='g')
plt.plot(x,y, label='Test Prediction', color='red')
plt.fill_between(x, y_min, y_max, facecolor='red', interpolate=True,alpha=0.3)
plt.legend(loc=2)
plt.savefig(output_name,bboxes='tight')
plt.show()
