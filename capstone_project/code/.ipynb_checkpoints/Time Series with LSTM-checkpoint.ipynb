# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
# First we read in the airline passenger
fileName = "data/international-airline-passengers.csv"
#fileName = "data/wolfer-sunspot-numbers-1770-to-1.csv"

# Load the data
df = pd.read_csv(fileName, engine='python', skipfooter=3)

# Process month to be a time format
print(df.iloc[0][0])
time_column_name = 'Month'
df[time_column_name]=pd.to_datetime(df[time_column_name], format='%Y-%m-%d')
df.set_index([time_column_name], inplace=True)

# Extract the raw data, without the dates
data = df.values
data = data.astype('float32')

# Initialize the Data Scaler
scaler = MinMaxScaler()

# Now we split the data and apply the data scalar
split = 50
#train_data =  scaler.fit_transform(data[0:split,:])
#test_data = scaler.fit_transform(data[split:,:])

train_data =  data[0:split,:]
test_data = data[split:,:]


print("train data", train_data.shape)

def future_data(data,lags=1,future=1):
    X, y = [], []
    for row in range(len(data) - lags - future):
        a = data[row:(row + lags), 0]
        X.append(a)
        y.append(data[row + lags+future-1, 0])
    return np.array(X), np.array(y)

def scale_array(y_vec):
    
    ymax = np.max(y_vec)
    ymin = np.min(y_vec)
    
    print("ymax",ymax)
    print("ymin",ymin)
    
    y_vec_scaled = np.zeros((len(y_vec),1))
    
    for k in range(0,len(y_vec)):
        y_vec_scaled[k][0] = (y_vec[k][0]-ymin)/(ymax-ymin)
    
    return y_vec_scaled,ymin,ymax

def invert_scaling(y_vec_scaled,ymin,ymax):
    
    y_vec = np.zeros(y_vec_scaled.shape)
        
        
    for k in range(0,len(y_vec_scaled)):
        y_vec[k] = ymin+(ymax-ymin)*y_vec_scaled[k]
    
    return y_vec

# Process the train and test data
train_data,train_min,train_max = scale_array(train_data)
test_data,test_min,test_max = scale_array(test_data)

lags=1
future=1

# Process the training data
X_train, y_train = future_data(train_data, lags,future)
X_test, y_test = future_data(test_data, lags,future)


# Reshape the arrays
X_train = np.reshape(X_train,(X_train.shape[0],1,X_train.shape[1]))
X_test = np.reshape(X_test,(X_test.shape[0],1,X_test.shape[1]))
# Out:
# 1949-01
# train data (50, 1)
# ymax 242.0
# ymin 104.0
# ymax 622.0
# ymin 180.0

# %%
model = Sequential()
model.add(LSTM(4, input_dim=lags))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=200, batch_size=2, verbose=1)
# Out:
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
#   from ipykernel import kernelapp as app
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(4, input_shape=(None, 1))`
#   from ipykernel import kernelapp as app
# Epoch 1/200
# 48/48 [==============================] - 1s 29ms/step - loss: 0.1997
# Epoch 2/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1694
# Epoch 3/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1429
# Epoch 4/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.1207
# Epoch 5/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0999
# Epoch 6/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0831
# Epoch 7/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0694
# Epoch 8/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0589
# Epoch 9/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0508
# Epoch 10/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0449
# Epoch 11/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0412
# Epoch 12/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0386
# Epoch 13/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0370
# Epoch 14/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0357
# Epoch 15/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0345
# Epoch 16/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0339
# Epoch 17/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0330
# Epoch 18/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0323
# Epoch 19/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0316
# Epoch 20/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0311
# Epoch 21/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0304
# Epoch 22/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0296
# Epoch 23/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0289
# Epoch 24/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0282
# Epoch 25/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0277
# Epoch 26/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0271
# Epoch 27/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0265
# Epoch 28/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0257
# Epoch 29/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0251
# Epoch 30/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0245
# Epoch 31/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0241
# Epoch 32/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0233
# Epoch 33/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0228
# Epoch 34/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0222
# Epoch 35/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0218
# Epoch 36/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0211
# Epoch 37/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0207
# Epoch 38/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0202
# Epoch 39/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0197
# Epoch 40/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0191
# Epoch 41/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0187
# Epoch 42/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0183
# Epoch 43/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0179
# Epoch 44/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0176
# Epoch 45/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0171
# Epoch 46/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0168
# Epoch 47/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0166
# Epoch 48/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0161
# Epoch 49/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0160
# Epoch 50/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 51/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 52/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0151
# Epoch 53/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 54/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0145
# Epoch 55/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 56/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0142
# Epoch 57/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0139
# Epoch 58/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 59/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 60/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0137
# Epoch 61/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0134
# Epoch 62/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0134
# Epoch 63/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0133
# Epoch 64/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0130
# Epoch 65/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0129
# Epoch 66/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0130
# Epoch 67/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0130
# Epoch 68/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 69/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0127
# Epoch 70/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 71/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0126
# Epoch 72/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0127
# Epoch 73/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 74/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 75/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 76/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 77/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 78/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 79/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 80/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 81/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 82/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 83/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 84/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 85/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 86/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 87/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 88/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 89/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 90/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0123
# Epoch 91/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 92/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 93/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 94/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 95/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0124
# Epoch 96/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 97/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 98/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 99/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 100/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 101/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0124
# Epoch 102/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 103/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 104/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 105/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 106/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 107/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 108/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 109/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 110/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 111/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 112/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 113/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 114/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 115/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 116/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 117/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 118/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 119/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 120/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 121/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 122/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 123/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0125
# Epoch 124/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 125/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0125
# Epoch 126/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 127/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 128/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0124
# Epoch 129/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 130/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 131/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 132/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 133/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 134/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 135/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 136/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 137/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 138/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 139/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 140/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 141/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0122A: 0s - loss: 0.0
# Epoch 142/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 143/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 144/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 145/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 146/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 147/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 148/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 149/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 150/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 151/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 152/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 153/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 154/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 155/200
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 156/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 157/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 158/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0124
# Epoch 159/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 160/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 161/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 162/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 163/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 164/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 165/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 166/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 167/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 168/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 169/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 170/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 171/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 172/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 173/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 174/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 175/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 176/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 177/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 178/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 179/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 180/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 181/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 182/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 183/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 184/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 185/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123
# Epoch 186/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 187/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 188/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 189/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 190/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0126
# Epoch 191/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 192/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 193/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 194/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 195/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 196/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 197/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 198/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 199/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 200/200
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0123

# %%
# generate predictions for training
uncertainty_samples = 1000

train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

print(test_predict.shape)

residuals = np.abs(y_test.reshape(-1, 1) - test_predict.reshape(-1, 1))

# Here we estimate the average residual 
sigma = 0.5*np.mean(residuals)
print("Estimated Sigma: ", sigma, np.std(residuals))




test_predictions = []
for k in range(0,uncertainty_samples):
    test_predict = model.predict(X_test)+np.random.normal(0.0, sigma, test_predict.shape)
    test_predictions.append(test_predict)

test_predictions = np.asarray(test_predictions)


# Unscale data
#test_predictions = scaler.inverse_transform(test_predictions)
y_train = invert_scaling(y_train,train_min,train_max)
train_predict = invert_scaling(train_predict,train_min,train_max)

# plot baseline and predictions
plt.plot(y_train, label='Training data');
plt.plot(train_predict[future:], label="Predictions on Training Data")
plt.legend(loc='best');
plt.title('Artificial Neural Network')
plt.show()



y = test_predict.flatten()[future:]

def return_min_max_prediction(test_predictions,i):
    
    y_vec = [ test_predictions[k][i][0] for k in range(0,test_predictions.shape[1])]
    
    ymin = np.min(y_vec)
    ymax = np.max(y_vec)
    
    return ymin,ymax

print(test_predict.shape)
print(test_predictions.shape)


y_min = np.asarray([return_min_max_prediction(test_predictions,i)[0] for i in range(0,len(y))])
y_max = np.asarray([return_min_max_prediction(test_predictions,i)[1] for i in range(0,len(y))])
x = np.arange(-future,len(y_min)-future)


# Unscale all of the data
#print(y_test.shape)
y_test = invert_scaling(y_test,test_min,test_max)
y_min = invert_scaling(y_min,test_min,test_max)
y_max = invert_scaling(y_max,test_min,test_max)
y = invert_scaling(y,test_min,test_max)

# Compute the root mean squared error
mse = ((y_test[:-1].reshape(-1, 1) - y.reshape(-1, 1)) ** 2).mean()

plt.title('Prediction quality: {:.2f} MSE ({:.2f} RMSE)'.format(mse, math.sqrt(mse)))
plt.plot(y_test.reshape(-1, 1), label='Test Data', color='#006699')
plt.plot(y, label='Test Prediction', color='red')
plt.fill_between(x, y_min, y_max, facecolor='red', interpolate=True,alpha=0.3)
plt.legend(loc='best');
plt.show()
# Out:
# (92, 1)
# Estimated Sigma:  0.0372227669754 0.0500556673138
# (92, 1)
# (1000, 92, 1)
