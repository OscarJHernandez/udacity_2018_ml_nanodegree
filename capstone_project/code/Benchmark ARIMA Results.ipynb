# %%
import ARIMA_routines as ar
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

# %%
# Now we compute the MSE and RMSE

def compute_metric(y_test,y_forecast):
    
    MSE = 0.0
    
    for i in range(0,len(y_test)):
        MSE+= (y_test[i]-y_forecast[i])**2
    
    MSE = MSE/float(len(y_test))
    
    RMSE = np.sqrt(MSE)
    
    return MSE, RMSE

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages


# EUR to CAD 

# First we read in the sunspot data
fileName = "data/EURUSD_15m_BID_01.01.2010-31.12.2016.csv"

# Load the data
df = pd.read_csv(fileName, engine='python', skipfooter=3)
df = df[['Time', 'Close']].copy()


# A bit of pre-processing to make it nicer
df['Time']=pd.to_datetime(df['Time'], format='%Y-%m-%d')
df.set_index(['Time'], inplace=True)


# Now we split our data into training vs testing
train_data = df['2016-01-01 00:00':'2016-05-01 00:00']
test_data = df['2016-05-01 00:15':'2016-06-30 23:45']

pMax,dMax,qMax = 2,2,2

AIC,RMS, ARIMAX_model, results = ar.fit_ARIMAX(pMax,dMax,qMax,train_data,test_data,"AIC")

forecast, stderr, conf = results.forecast(len(test_data))

# Create a Dataframe with the forecast
df = pd.DataFrame(columns=['DATE', 'FORECAST'])
for i in range(len(test_data)):
    df.loc[i] = [test_data.index[i], forecast[i]]
    
df['DATE']=pd.to_datetime(df['DATE'], format='%Y-%m-%d')
df.set_index(['DATE'], inplace=True)   

# Create a Dataframe for the upper bound of the forecast
df_conf_upper = pd.DataFrame(columns=['DATE', 'FORECAST_UPPER'])
df_conf_lower = pd.DataFrame(columns=['DATE', 'FORECAST_LOWER'])

for i in range(len(test_data)):
    df_conf_upper.loc[i] = [test_data.index[i], conf[i][1]]
    df_conf_lower.loc[i] = [test_data.index[i], conf[i][0]]


df_conf_upper['DATE']=pd.to_datetime(df_conf_upper['DATE'], format='%Y-%m-%d')
df_conf_lower['DATE']=pd.to_datetime(df_conf_lower['DATE'], format='%Y-%m-%d')

df_conf_upper.set_index(['DATE'], inplace=True)   
df_conf_lower.set_index(['DATE'], inplace=True)
# Out:
# The smallest AIC is -139843.63818170418 for model ARMA(2, 0, 2)

# %%
#============================================
# Compute the metrics of the model
#============================================
df_original = pd.read_csv(fileName, engine='python', skipfooter=3)
print(df_original.describe(), '\n')


y_test=[test_data['Close'][k] for k in range(0,len(test_data))]
y_forecast =[df['FORECAST'][k] for k in range(0,len(df))]

MSE, RMSE = compute_metric(y_test,y_forecast)
print('MSE: ',MSE,' RMS: ', RMSE)


#============================================
# Here we plot the results of the above fit
#=============================================
plt.plot(train_data,color='blue')
plt.plot(test_data,color='blue')
plt.ylabel('EURO/USD exchange rate',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.savefig('EURO_USD_exchange_rate.pdf',bboxes='tight')
plt.show()


#=============================================
plt.clf()
plt.plot(train_data,color='b',label='Training data')
plt.plot(test_data, color='g',label='Testing data')
plt.plot(df_conf_upper,color='r')
plt.plot(df_conf_lower,color='r')
plt.fill_between(df_conf_upper.index,df_conf_lower.iloc[:,0],df_conf_upper.iloc[:,0],alpha=0.2, color='r',label='Prediction')
plt.plot(df,color='r')
plt.legend()
plt.ylabel('EURO/USD exchange rate',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.savefig('EURO_USD_exchange_rate_with_Forecast.pdf',bboxes='tight')
plt.show()
#=============================================
# Out:
#        International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# count                                         144.000000
# mean                                          280.298611
# std                                           119.966317
# min                                           104.000000
# 25%                                           180.000000
# 50%                                           265.500000
# 75%                                           360.500000
# max                                           622.000000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-0da31b9f57e3> in <module>()
#       6
#       7
# ----> 8 y_test=[test_data['Close'][k] for k in range(0,len(test_data))]
#       9 y_forecast =[df['FORECAST'][k] for k in range(0,len(df))]
#      10
#
# <ipython-input-87-0da31b9f57e3> in <listcomp>(.0)
#       6
#       7
# ----> 8 y_test=[test_data['Close'][k] for k in range(0,len(test_data))]
#       9 y_forecast =[df['FORECAST'][k] for k in range(0,len(df))]
#      10
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages


# First we read in the sunspot data
fileName = "data/international-airline-passengers.csv"

# Load the data
df = pd.read_csv(fileName, engine='python', skipfooter=3)
# Process month to be a time format
df['Month']=pd.to_datetime(df['Month'], format='%Y-%m-%d')
df.set_index(['Month'], inplace=True)


# Split our data into training vs testing
train_data = df['1949-01-01':'1955-01-01']
test_data = df['1955-02-01':'1956-01-01']
validation_data = df['1956-02-01':'1960-12-01']



pMax,dMax,qMax,t = 1,1,2,12

AIC,RMS, SARIMAX_model, results = ar.fit_SARIMAX(pMax,dMax,qMax,t,train_data,test_data)

# Show the predictions
pred  =  results.get_forecast(validation_data.index[-1])
pred_ci = pred.conf_int()
pred_mean = pred.predicted_mean
# Out:
# The smallest RMS is 10.096863938296307 for model SARIMAX(1, 1, 1)x(1, 0, 0, 12)7

# %%
#============================================
# Compute the metrics of the model
#============================================

print(df.describe(), '\n')


y_test=[validation_data.iloc[k,0] for k in range(0,len(validation_data))]
y_forecast =[pred_mean[k] for k in range(0,len(pred_mean))]

MSE, RMSE = compute_metric(y_test,y_forecast)
print('MSE: ',MSE,' RMS: ', RMSE)



plt.clf()
plt.plot(train_data,color='b')
plt.plot(test_data,color='b')
plt.plot(validation_data,color='b')
plt.ylabel('Number of Airline Passengers',fontsize=15)
plt.xlabel('Date',fontsize=20)
plt.savefig('Airline_Passengers.pdf',bboxes='tight')
plt.show()

plt.clf()
#plt.plot(results.get_prediction(dynamic=False).predicted_mean[train_data.index[0]:train_data.index[-1]])
plt.fill_between(pred_ci.index,pred_ci.iloc[:,0],pred_ci.iloc[:,1],alpha=0.2, color='r')
plt.plot(pred_mean,label="Forecast",color='r')
plt.plot(train_data,label="Training data",color='b')
plt.plot(test_data,color='b')
plt.plot(validation_data,label='Testing data',color='g')
plt.ylabel('Number of Airline Passengers',fontsize=15)
plt.xlabel('Date',fontsize=20)
plt.legend(loc=2)
plt.savefig('Airline_Passengers_Forecast.pdf',bboxes='tight')
plt.show()
# Out:
#        International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# count                                         144.000000
# mean                                          280.298611
# std                                           119.966317
# min                                           104.000000
# 25%                                           180.000000
# 50%                                           265.500000
# 75%                                           360.500000
# max                                           622.000000
#
# MSE:  1878.63101438  RMS:  43.3431772529

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

#=========================================
# Sunspot data set
#=========================================

dta = sm.datasets.sunspots.load_pandas().data
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('1700', '2008'))
del dta["YEAR"]

# Create a training vs test data set
train_data = dta['1700':'1900']
test_data = dta['1901':'2008']

pMax,dMax,qMax = 5,1,5

# Fit the ARMA model
AIC,RMS,ARMA_model,results = ar.fit_ARIMAX(pMax,dMax,qMax,train_data,test_data,"RMS")

forecast, stderr, conf = results.forecast(400)


# Create a Dataframe with the forecast
df = pd.DataFrame(columns=['DATE', 'FORECAST'])
for i in range(len(test_data)):
    df.loc[i] = [test_data.index[i], forecast[i]]
df['DATE']=pd.to_datetime(df['DATE'], format='%Y-%m-%d')
df.set_index(['DATE'], inplace=True)   

# Create a Dataframe for the upper bound of the forecast
df_conf_upper = pd.DataFrame(columns=['DATE', 'FORECAST_UPPER'])
df_conf_lower = pd.DataFrame(columns=['DATE', 'FORECAST_LOWER'])

for i in range(len(test_data)):
    df_conf_upper.loc[i] = [test_data.index[i], conf[i][1]]
    df_conf_lower.loc[i] = [test_data.index[i], conf[i][0]]


df_conf_upper['DATE']=pd.to_datetime(df_conf_upper['DATE'], format='%Y-%m-%d')
df_conf_lower['DATE']=pd.to_datetime(df_conf_lower['DATE'], format='%Y-%m-%d')

df_conf_upper.set_index(['DATE'], inplace=True)   
df_conf_lower.set_index(['DATE'], inplace=True)
# Out:
# The smallest RMS is 49.013233274914754 for model ARMA(5, 0, 4)

# %%
print(dta.describe(),'\n')



plt.plot(train_data,color='b')
plt.plot(test_data,color='b')
plt.ylabel('Number of Sunspots',fontsize=15)
plt.xlabel('Date',fontsize=20)
plt.savefig('Sunspot.pdf',bboxes='tight')
plt.show()


plt.plot(train_data,color='b',label='Training data')
plt.plot(test_data,color='g',label='Test data')
plt.plot(df_conf_upper,color='r')
plt.plot(df_conf_lower,color='r')
plt.fill_between(df_conf_upper.index,df_conf_lower.iloc[:,0],df_conf_upper.iloc[:,0],alpha=0.2, color='r')
plt.plot(df,color='r',label='Forecast')
plt.legend(loc=2)
plt.ylabel('Number of Sunspots',fontsize=15)
plt.xlabel('Date',fontsize=20)
plt.savefig('Sunspot_Forecast.pdf',bboxes='tight')
plt.show()
# Out:
#        SUNACTIVITY
# count   309.000000
# mean     49.752104
# std      40.452595
# min       0.000000
# 25%      16.000000
# 50%      40.000000
# 75%      69.800000
# max     190.200000

# %%
# First we read in the sunspot data
fileName = "data/total-annual-rainfall-in-inches-.csv"

# Load the data
df = pd.read_csv(fileName, engine='python', skipfooter=3)
# A bit of pre-processing to make it nicer
df['Year']=pd.to_datetime(df['Year'], format='%Y-%m-%d')
df.set_index(['Year'], inplace=True)

# Now we split our data into training vs testing
train_data = df['1813-01-01':'1860-01-01']
test_data = df['1861-01-01':'1912-01-01']


pMax,dMax,qMax,t = 2,1,0,12

AIC,RMS, SARIMAX_model, results = ar.fit_SARIMAX(pMax,dMax,qMax,t,train_data,test_data,"AIC")

pred  =  results.get_forecast("1912-01-01")
pred_ci = pred.conf_int()
pred_mean = pred.predicted_mean

# SARIMAX(2, 1, 0)x(2, 1, 0, 12)
# Plot the results of fitting procedure
plt.clf()
plt.plot(results.get_prediction(dynamic=False).predicted_mean['1949-01-01':'1956-01-01'])
plt.fill_between(pred_ci.index,pred_ci.iloc[:,0],pred_ci.iloc[:,1],alpha=0.2, color='r')
plt.plot(pred_mean,label="Forecast",c='r')
plt.plot(train_data,label="Training data", c='b')
plt.plot(test_data,label="Testing data")
plt.legend()
plt.show()
# Out:
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(0, 0, 0)x(1, 0, 0, 12) - AIC:221.40205074011988 - RMS:7.3335966894747795
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(0, 0, 0)x(2, 0, 0, 12) - AIC:148.8446558567672 - RMS:6.200234837304218
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(0, 1, 0)x(1, 0, 0, 12) - AIC:231.15462406528673 - RMS:8.433507289094589
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(0, 1, 0)x(2, 0, 0, 12) - AIC:157.87768785507876 - RMS:8.960425327062456
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(1, 0, 0)x(0, 1, 0, 12) - AIC:213.47323534134478 - RMS:6.944126516803605
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(1, 0, 0)x(1, 1, 0, 12) - AIC:141.29237894339508 - RMS:5.518790406396317
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(1, 0, 0)x(2, 0, 0, 12) - AIC:141.91302669482593 - RMS:5.955125451598463
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(1, 1, 0)x(1, 0, 0, 12) - AIC:217.3576100541817 - RMS:7.799990882761691
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(1, 1, 0)x(1, 1, 0, 12) - AIC:148.5015694059692 - RMS:9.201801910985974
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(1, 1, 0)x(2, 0, 0, 12) - AIC:146.85211906664065 - RMS:7.973056817856303
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 0, 0)x(0, 1, 0, 12) - AIC:208.51050511965641 - RMS:6.959553630157458
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 0, 0)x(1, 0, 0, 12) - AIC:207.7526011892412 - RMS:7.267598817598249
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 0, 0)x(1, 1, 0, 12) - AIC:135.16979452142348 - RMS:5.836394554748273
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 0, 0)x(2, 0, 0, 12) - AIC:135.52255192764437 - RMS:6.0291176970508005
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 1, 0)x(1, 0, 0, 12) - AIC:207.026341008168 - RMS:5.607196736698567
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 1, 0)x(1, 1, 0, 12) - AIC:136.4691159606647 - RMS:7.621564153061058
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# SARIMAX(2, 1, 0)x(2, 0, 0, 12) - AIC:138.08503169345158 - RMS:6.918235156781117
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# The smallest AIC is 55.85142973896112 for model SARIMAX(2, 1, 0)x(2, 1, 0, 12)
# /home/javier/anaconda3/envs/py35/lib/python3.5/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
